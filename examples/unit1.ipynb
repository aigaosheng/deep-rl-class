# %% [markdown]
# # Unit 1: Train your first Deep Reinforcement Learning Agent 🤖
#
# ![Cover](https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/thumbnail.jpg)
#
# In this notebook, you'll train your **first Deep Reinforcement Learning agent** a Lunar Lander agent that will learn to **land correctly on the Moon 🌕**. Using [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) a Deep Reinforcement Learning library, share them with the community, and experiment with different configurations
#
# ⬇️ Here is an example of what **you will achieve in just a couple of minutes.** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - [LunarLander-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ### The library used 📚
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Gymnasium**, the environment library.
# - Be able to use **Stable-Baselines3**, the deep reinforcement learning library.
# - Be able to **push your trained agent to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
# - 🎓 **Earn a certificate of completion** by completing 80% of the assignments.
#
# And more!
#
# Check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
# The best way to keep in touch and ask questions is **to join our discord server** to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
#
# Before diving into the notebook, you need to:
#
# 🔲 📝 **[Read Unit 0](https://huggingface.co/deep-rl-course/unit0/introduction)** that gives you all the **information about the course and helps you to onboard** 🤗
#
# 🔲 📚 **Develop an understanding of the foundations of Reinforcement learning** (RL process, Rewards hypothesis...) by [reading Unit 1](https://huggingface.co/deep-rl-course/unit1/introduction).

# %% [markdown]
# ## A small recap of Deep Reinforcement Learning 📚
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# Let's do a small recap on what we learned in the first Unit:
#
# - Reinforcement Learning is a **computational approach to learning from actions**. We build an agent that learns from the environment by **interacting with it through trial and error** and receiving rewards (negative or positive) as feedback.
#
# - The goal of any RL agent is to **maximize its expected cumulative reward** (also called expected return) because RL is based on the _reward hypothesis_, which is that all goals can be described as the maximization of an expected cumulative reward.
#
# - The RL process is a **loop that outputs a sequence of state, action, reward, and next state**.
#
# - To calculate the expected cumulative reward (expected return), **we discount the rewards**: the rewards that come sooner (at the beginning of the game) are more probable to happen since they are more predictable than the long-term future reward.
#
# - To solve an RL problem, you want to **find an optimal policy**; the policy is the "brain" of your AI that will tell us what action to take given a state. The optimal one is the one that gives you the actions that max the expected return.
#
# There are **two** ways to find your optimal policy:
#
# - By **training your policy directly**: policy-based methods.
# - By **training a value function** that tells us the expected return the agent will get at each state and use this function to define our policy: value-based methods.
#
# - Finally, we spoke about Deep RL because **we introduce deep neural networks to estimate the action to take (policy-based) or to estimate the value of a state (value-based) hence the name "deep."**

# %% [markdown]
# # Let's train our first Deep Reinforcement Learning agent and upload it to the Hub 🚀
#
# ## Get a certificate 🎓
#
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
#
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Install dependencies and create a virtual screen 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones.
#
# - `gymnasium[box2d]`: Contains the LunarLander-v2 environment 🌛
# - `stable-baselines3[extra]`: The deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
#
# To make things easier, we created a script to install all these dependencies.

# %%
# !apt install swig cmake

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %% [markdown]
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install virtual screen libraries and create and run a virtual screen 🖥

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %% [markdown]
# To make sure the new installed libraries are used, **sometimes it's required to restart the notebook runtime**. The next cell will force the **runtime to crash, so you'll need to connect again and run the code starting from here**. Thanks to this trick, **we will be able to run our virtual screen.**

# %%
import os
os.kill(os.getpid(), 9)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Import the packages 📦
#
# One additional library we import is huggingface_hub **to be able to upload and download trained models from the hub**.
#
#
# The Hugging Face Hub 🤗 works as a central place where anyone can share and explore models and datasets. It has versioning, metrics, visualizations and other features that will allow you to easily collaborate with others.
#
# You can see here all the Deep reinforcement Learning models available here👉 https://huggingface.co/models?pipeline_tag=reinforcement-learning&sort=downloads

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# 2025-05-20 15:24:06.558216: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-20 15:24:06.677706: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747725846.719769    6555 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747725846.733944    6555 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747725846.849574    6555 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747725846.849615    6555 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747725846.849621    6555 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747725846.849624    6555 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-20 15:24:06.866426: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import GPUtil
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 | 24% |  9% |

# %% [markdown]
# ## Understand Gymnasium and how it works 🤖
#
# 🏋 The library containing our environment is called Gymnasium.
# **You'll use Gymnasium a lot in Deep Reinforcement Learning.**
#
# Gymnasium is the **new version of Gym library** [maintained by the Farama Foundation](https://farama.org/).
#
# The Gymnasium library provides two things:
#
# - An interface that allows you to **create RL environments**.
# - A **collection of environments** (gym-control, atari, box2D...).
#
# Let's look at an example, but first let's recall the RL loop.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# At each step:
# - Our Agent receives a **state (S0)** from the **Environment** — we receive the first frame of our game (Environment).
# - Based on that **state (S0),** the Agent takes an **action (A0)** — our Agent will move to the right.
# - The environment transitions to a **new** **state (S1)** — new frame.
# - The environment gives some **reward (R1)** to the Agent — we’re not dead *(Positive Reward +1)*.
#
#
# With Gymnasium:
#
# 1️⃣ We create our environment using `gymnasium.make()`
#
# 2️⃣ We reset the environment to its initial state with `observation = env.reset()`
#
# At each step:
#
# 3️⃣ Get an action using our model (in our example we take a random action)
#
# 4️⃣ Using `env.step(action)`, we perform this action in the environment and get
# - `observation`: The new state (st+1)
# - `reward`: The reward we get after executing the action
# - `terminated`: Indicates if the episode terminated (agent reach the terminal state)
# - `truncated`: Introduced with this new version, it indicates a timelimit or if an agent go out of bounds of the environment for instance.
# - `info`: A dictionary that provides additional information (depends on the environment).
#
# For more explanations check this 👉 https://gymnasium.farama.org/api/env/#gymnasium.Env.step
#
# If the episode is terminated:
# - We reset the environment to its initial state with `observation = env.reset()`
#
# **Let's look at an example!** Make sure to read the code

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v3")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  # print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # print("Next state:", observation)
  # print("Reward:", reward)
  # print("Terminated:", terminated)
  # print("Truncated:", truncated)
  # print("Info:", info)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()

# %% [markdown]
# ## Create the LunarLander environment 🌛 and understand how it works
#
# ### [The environment 🎮](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# In this first tutorial, we’re going to train our agent, a [Lunar Lander](https://gymnasium.farama.org/environments/box2d/lunar_lander/), **to land correctly on the moon**. To do that, the agent needs to learn **to adapt its speed and position (horizontal, vertical, and angular) to land correctly.**
#
# ---
#
#
# 💡 A good habit when you start to use an environment is to check its documentation
#
# 👉 https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# ---

# %% [markdown]
# Let's see what the Environment looks like:

# %%
import gymnasium as gym

# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [  8.792689  -45.911217    2.8569255  -4.8779116  -1.0056503  -0.9024622
#    0.2392908   0.7008388]

# %% [markdown]
# We see with `Observation Space Shape (8,)` that the observation is a vector of size 8, where each value contains different information about the lander:
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg contact point has touched the land (boolean)
# - If the right leg contact point has touched the land (boolean)

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 2

# %% [markdown]
# The action space (the set of possible actions the agent can take) is discrete with 4 actions available 🎮:
#
# - Action 0: Do nothing,
# - Action 1: Fire left orientation engine,
# - Action 2: Fire the main engine,
# - Action 3: Fire right orientation engine.
#
# Reward function (the function that will give a reward at each timestep) 💰:
#
# After every step a reward is granted. The total reward of an episode is the **sum of the rewards for all the steps within that episode**.
#
# For each step, the reward:
#
# - Is increased/decreased the closer/further the lander is to the landing pad.
# -  Is increased/decreased the slower/faster the lander is moving.
# - Is decreased the more the lander is tilted (angle not horizontal).
# - Is increased by 10 points for each leg that is in contact with the ground.
# - Is decreased by 0.03 points each frame a side engine is firing.
# - Is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an **additional reward of -100 or +100 points for crashing or landing safely respectively.**
#
# An episode is **considered a solution if it scores at least 200 points.**

# %% [markdown]
# #### Vectorized Environment
#
# - We create a vectorized environment (a method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - We have studied our environment and we understood the problem: **being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine**. Now let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/sb3.png" alt="Stable Baselines3">

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the SOTA (state of the art) Deep Reinforcement Learning algorithms that you'll study during this course](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#example%5D).
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **give us a probability distribution over actions**.

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You **create your environment** (in our case it was done above)
#
# 2️⃣ You define the **model you want to use and instantiate this model** `model = PPO("MlpPolicy")`
#
# 3️⃣ You **train the agent** with `model.learn` and define the number of training timesteps
#
# ```
# # Create environment
# env = gym.make('LunarLander-v2')
#
# # Instantiate the agent
# model = PPO('MlpPolicy', env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# ```

# %% [markdown]
# #### Solution

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 8,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## Train the PPO agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~20min, but you can use fewer timesteps if you just want to try it out.
# - During the training, take a ☕ break you deserved it 🤗

# %% [markdown]
# #### Solution

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000, progress_bar=True)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.8     |
# |    ep_rew_mean     | -229     |
# | time/              |          |
# |    fps             | 1501     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.1         |
# |    ep_rew_mean          | -178         |
# | time/                   |              |
# |    fps                  | 1400         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0037581185 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00454      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.91e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.1         |
# |    ep_rew_mean          | -173         |
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0056945477 |
# |    clip_fraction        | 0.00452      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0032      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+03      |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00541     |
# |    value_loss           | 2.8e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.5         |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 1497         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0018104012 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0036      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.44e+03     |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93           |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 1512         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0029509012 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00461     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13e+03     |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 4.36e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.4         |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 1531         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0018203944 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0484      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 4.82e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.4        |
# |    ep_rew_mean          | -158        |
# | time/                   |             |
# |    fps                  | 1538        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.009257918 |
# |    clip_fraction        | 0.0148      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0232     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.48e+03    |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 2.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.4        |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 1546        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006943863 |
# |    clip_fraction        | 0.00708     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.000217   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 671         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 1.64e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 92.4       |
# |    ep_rew_mean          | -158       |
# | time/                   |            |
# |    fps                  | 1552       |
# |    iterations           | 9          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.00410597 |
# |    clip_fraction        | 0.00122    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.000371   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.65e+03   |
# |    n_updates            | 64         |
# |    policy_gradient_loss | -0.00473   |
# |    value_loss           | 3.21e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.6         |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 1556         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0015524013 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000584     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18e+03     |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 4.25e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.2        |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1560        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.008401319 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00124    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 517         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 1.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.3        |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 1562        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006137806 |
# |    clip_fraction        | 0.00537     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00189    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 663         |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.6         |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1565         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0055160755 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.00643     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+03     |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00674     |
# |    value_loss           | 4.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.5        |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 1566        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006431029 |
# |    clip_fraction        | 0.00891     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000104   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 693         |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 1.57e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.4         |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 1570         |
# |    iterations           | 15           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0073355865 |
# |    clip_fraction        | 0.00867      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00185     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 966          |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00647     |
# |    value_loss           | 2.05e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006104337 |
# |    clip_fraction        | 0.00867     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -3.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 2.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.9        |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.007862565 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.0261     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 446         |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 1.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010721659 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 3.8e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 889         |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.0097     |
# |    value_loss           | 1.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 19          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.014132077 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000258   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 387         |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 772         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 20          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008883995 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000523   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 297         |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 598         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 1569         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0038390504 |
# |    clip_fraction        | 0.00769      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.00318     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1571         |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0051718047 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.00046     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 399          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 988          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1572        |
# |    iterations           | 23          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.006577718 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 250         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 125          |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 1574         |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0070370953 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.00471      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+03     |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 25          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.008532021 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.0149     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 251         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 521         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 26          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010067084 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 736         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00981    |
# |    value_loss           | 1.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.011170728 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.199      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 585         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | -102         |
# | time/                   |              |
# |    fps                  | 1577         |
# |    iterations           | 28           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0065454766 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0533       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 197          |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00936     |
# |    value_loss           | 388          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | -95.6        |
# | time/                   |              |
# |    fps                  | 1579         |
# |    iterations           | 29           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0079984795 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 312          |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 925          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 144          |
# |    ep_rew_mean          | -94          |
# | time/                   |              |
# |    fps                  | 1579         |
# |    iterations           | 30           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0071437405 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0644       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 344          |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00922     |
# |    value_loss           | 649          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | -92.5        |
# | time/                   |              |
# |    fps                  | 1579         |
# |    iterations           | 31           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0064298776 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.321        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 266          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | -85.4        |
# | time/                   |              |
# |    fps                  | 1581         |
# |    iterations           | 32           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0021838262 |
# |    clip_fraction        | 0.00134      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 988          |
# |    n_updates            | 248          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 1.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -79.5       |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 33          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008608814 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 235         |
# |    n_updates            | 256         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 468         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | -76.2       |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 34          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005238129 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 139         |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 347         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | -66         |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 35          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.007889725 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 272         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 363         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -56.6       |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004185174 |
# |    clip_fraction        | 0.0109      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 367         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | -50.7        |
# | time/                   |              |
# |    fps                  | 1583         |
# |    iterations           | 37           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0072797267 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.266        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 211          |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 427          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 1584        |
# |    iterations           | 38          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007437256 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 296         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 304         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | -46.5        |
# | time/                   |              |
# |    fps                  | 1584         |
# |    iterations           | 39           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0053617884 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 304          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 282          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -44.5       |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 40          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008564539 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.8        |
# |    n_updates            | 312         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -41         |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.016214559 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 46.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 171          |
# |    ep_rew_mean          | -39          |
# | time/                   |              |
# |    fps                  | 1585         |
# |    iterations           | 42           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0040889466 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.1         |
# |    n_updates            | 328          |
# |    policy_gradient_loss | -0.00648     |
# |    value_loss           | 247          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -35.9       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 43          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.012627713 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 336         |
# |    policy_gradient_loss | -0.00502    |
# |    value_loss           | 57.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -35.8       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 44          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008913621 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 344         |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 251         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 45          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.006707833 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.8        |
# |    n_updates            | 352         |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 122         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | -26.8        |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 46           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0060272566 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 282          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 174          |
# |    ep_rew_mean          | -26.1        |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 47           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0074345926 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.706        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91           |
# |    n_updates            | 368          |
# |    policy_gradient_loss | -0.00715     |
# |    value_loss           | 296          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 48          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006850868 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 376         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 239         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -17.8        |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 49           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0059535517 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.719        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 384          |
# |    policy_gradient_loss | -0.00603     |
# |    value_loss           | 352          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 181          |
# |    ep_rew_mean          | -15.9        |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 50           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0043279096 |
# |    clip_fraction        | 0.00574      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 392          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 195          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -15.3       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.014110409 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.07        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 22          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | -14.2      |
# | time/                   |            |
# |    fps                  | 1586       |
# |    iterations           | 52         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01591611 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 74.7       |
# |    n_updates            | 408        |
# |    policy_gradient_loss | -0.011     |
# |    value_loss           | 198        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | -13.2        |
# | time/                   |              |
# |    fps                  | 1586         |
# |    iterations           | 53           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0058947606 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 416          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | -15.5       |
# | time/                   |             |
# |    fps                  | 1586        |
# |    iterations           | 54          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013548102 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 67.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | -15.1        |
# | time/                   |              |
# |    fps                  | 1585         |
# |    iterations           | 55           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# ...
# |    iterations           | 960        |
# |    time_elapsed         | 617        |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.02006751 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.601     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 7672       |
# |    policy_gradient_loss | -0.00173   |
# |    value_loss           | 2.35       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 961         |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 984064      |
# | train/                  |             |
# |    approx_kl            | 0.004801126 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54        |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 7.41        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 962          |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0051846458 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 7688         |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 3.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 963          |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 986112       |
# | train/                  |              |
# |    approx_kl            | 0.0027401512 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 252          |
# |    n_updates            | 7696         |
# |    policy_gradient_loss | 0.00166      |
# |    value_loss           | 728          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 964          |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0008566723 |
# |    clip_fraction        | 0.00061      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 667          |
# |    n_updates            | 7704         |
# |    policy_gradient_loss | -0.000995    |
# |    value_loss           | 1.27e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 965          |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 988160       |
# | train/                  |              |
# |    approx_kl            | 0.0036156685 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.23         |
# |    n_updates            | 7712         |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 50.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 966          |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0010503859 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 310          |
# |    n_updates            | 7720         |
# |    policy_gradient_loss | -0.000411    |
# |    value_loss           | 766          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 967         |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 990208      |
# | train/                  |             |
# |    approx_kl            | 0.014457597 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.42        |
# |    n_updates            | 7728        |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 968         |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.000867918 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 851         |
# |    n_updates            | 7736        |
# |    policy_gradient_loss | -0.000679   |
# |    value_loss           | 1.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 969         |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.003338129 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 7744        |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 972         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 970          |
# |    time_elapsed         | 623          |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0049711308 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.711        |
# |    n_updates            | 7752         |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 7.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 290          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 971          |
# |    time_elapsed         | 624          |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0025703264 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.63         |
# |    n_updates            | 7760         |
# |    policy_gradient_loss | 0.000377     |
# |    value_loss           | 27.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 290         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 1593        |
# |    iterations           | 972         |
# |    time_elapsed         | 624         |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.014195584 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.669       |
# |    n_updates            | 7768        |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 9.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 283          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 973          |
# |    time_elapsed         | 625          |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0068486873 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.48         |
# |    n_updates            | 7776         |
# |    policy_gradient_loss | -0.000602    |
# |    value_loss           | 15.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 1593         |
# |    iterations           | 974          |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0010301827 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.694        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 326          |
# |    n_updates            | 7784         |
# |    policy_gradient_loss | 0.000116     |
# |    value_loss           | 904          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 1592         |
# |    iterations           | 975          |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0019497651 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83           |
# |    n_updates            | 7792         |
# |    policy_gradient_loss | -0.000914    |
# |    value_loss           | 431          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 1592        |
# |    iterations           | 976         |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.005729964 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8         |
# |    n_updates            | 7800        |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 28.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 1592         |
# |    iterations           | 977          |
# |    time_elapsed         | 628          |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0010326381 |
# |    clip_fraction        | 0.00134      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.7         |
# |    n_updates            | 7808         |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 388          |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Evaluate the agent 📈
# - Remember to wrap the environment in a [Monitor](https://stable-baselines3.readthedocs.io/en/master/common/monitor.html).
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
# - In the next step,  we'll see **how to automatically evaluate and share your agent to compete in a leaderboard, but for now let's do it ourselves**
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
# TODO: Evaluate the agent
# Create a new environment for evaluation
eval_env =

# Evaluate the model with 10 evaluation episodes and deterministic=True
mean_reward, std_reward =

# Print the results

# %% [markdown]
# #### Solution

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=265.72 +/- 25.489855589916043

# %% [markdown]
# - In my case, I got a mean reward of `200.20 +/- 20.80` after training for 1 million steps, which means that our lunar lander agent is ready to land on the moon 🌛🥳.

# %% [markdown]
# ## Publish our trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20
#
# Here's an example of a Model Card (with Space Invaders):

# %% [markdown]
# By using `package_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account on Hugging Face ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# Let's fill the `package_to_hub` function:
# - `model`: our trained model.
# - `model_name`: the name of the trained model that we defined in `model_save`
# - `model_architecture`: the model architecture we used, in our case PPO
# - `env_id`: the name of the environment, in our case `LunarLander-v2`
# - `eval_env`: the evaluation environment defined in eval_env
# - `repo_id`: the name of the Hugging Face Hub Repository that will be created/updated `(repo_id = {username}/{repo_name})`
#
# 💡 **A good name is {username}/{model_architecture}-{env_id}**
#
# - `commit_message`: message of the commit

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id =

# TODO: Define the name of the environment
env_id =

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))])


# TODO: Define the model architecture we used
model_architecture = ""

## TODO: Define the commit message
commit_message = ""

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)

# %% [markdown]
# #### Solution

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "aitechgs/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/gs/miniconda3/envs/rl/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmpbptm4o3k/-step-0-to-step-1000.mp4
# MoviePy - Building video /tmp/tmpbptm4o3k/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /tmp/tmpbptm4o3k/-step-0-to-step-1000.mp4
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpbptm4o3k/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:20.00, start: 0.000000, bitrate: 69 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 600x400, 64 kb/s, 50 fps, 50 tbr, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc61.3.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f1f6e0d180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f1f6e0d180] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55f1f6e0d180] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmp_z7odck0/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 600x400, q=2-31, 50 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 size=       0kB time=N/A bitrate=N/A speed=N/A
# MoviePy - Done !
# MoviePy - video ready /tmp/tmpbptm4o3k/-step-0-to-step-1000.mp4
# [out#0/mp4 @ 0x55f1f6d3dfc0] video:146kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 8.452586%
# frame= 1000 fps=0.0 q=-1.0 Lsize=     159kB time=00:00:19.94 bitrate=  65.1kbits/s speed=75.1x
# [libx264 @ 0x55f1f6e0d180] frame I:5     Avg QP: 9.27  size:  1928
# [libx264 @ 0x55f1f6e0d180] frame P:272   Avg QP:21.49  size:   221
# [libx264 @ 0x55f1f6e0d180] frame B:723   Avg QP:24.04  size:   110
# [libx264 @ 0x55f1f6e0d180] consecutive B-frames:  1.7%  3.4%  6.9% 88.0%
# [libx264 @ 0x55f1f6e0d180] mb I  I16..4: 84.5%  9.5%  6.0%
# [libx264 @ 0x55f1f6e0d180] mb P  I16..4:  0.2%  0.4%  0.1%  P16..4:  1.8%  0.5%  0.2%  0.0%  0.0%    skip:96.9%
# [libx264 @ 0x55f1f6e0d180] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  2.2%  0.3%  0.0%  direct: 0.1%  skip:97.2%  L0:53.8% L1:45.2% BI: 1.0%
# [libx264 @ 0x55f1f6e0d180] 8x8 transform intra:24.0% inter:17.2%
# [libx264 @ 0x55f1f6e0d180] coded y,uvDC,uvAC intra: 6.1% 9.4% 8.4% inter: 0.2% 0.2% 0.2%
# [libx264 @ 0x55f1f6e0d180] i16 v,h,dc,p: 82% 13%  5%  0%
# [libx264 @ 0x55f1f6e0d180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 16% 77%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x55f1f6e0d180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 19% 55%  2%  2%  1%  3%  1%  4%
# [libx264 @ 0x55f1f6e0d180] i8c dc,h,v,p: 92%  5%  3%  0%
# [libx264 @ 0x55f1f6e0d180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f1f6e0d180] ref P L0: 70.2%  2.1% 18.4%  9.3%
# [libx264 @ 0x55f1f6e0d180] ref B L0: 68.5% 26.3%  5.2%
# [libx264 @ 0x55f1f6e0d180] ref B L1: 93.1%  6.9%
# [libx264 @ 0x55f1f6e0d180] kb/s:59.60
# ℹ Pushing repo aitechgs/ppo-LunarLander-v2 to the Hugging Face Hub
# ppo-LunarLander-v2.zip:   0%|          | 0.00/149k [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/88.7k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# replay.mp4:   0%|          | 0.00/162k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/44.1k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/aitechgs/ppo-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/aitechgs/ppo-LunarLander-v2/commit/deca218da709894e68402d145a6f841c295f0bda', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='deca218da709894e68402d145a6f841c295f0bda', pr_url=None, repo_url=RepoUrl('https://huggingface.co/aitechgs/ppo-LunarLander-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='aitechgs/ppo-LunarLander-v2'), pr_revision=None, pr_num=None)

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Reinforcement Learning agent. The script above should have displayed a link to a model repository such as https://huggingface.co/osanseviero/test_sb3. When you go to this link, you can:
# * See a video preview of your agent at the right.
# * Click "Files and versions" to see all the files in the repository.
# * Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# * A model card (`README.md` file) which gives a description of the model
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# Compare the results of your LunarLander-v2 with your classmates using the leaderboard 🏆 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# ## Load a saved LunarLander model from the Hub 🤗
# Thanks to [ironbar](https://github.com/ironbar) for the contribution.
#
# Loading a saved model from the Hub is really easy.
#
# You go to https://huggingface.co/models?library=stable-baselines3 to see the list of all the Stable-baselines3 saved models.
# 1. You select one and copy its repo_id
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/copy-id.png" alt="Copy-id"/>

# %% [markdown]
# 2. Then we just need to use load_from_hub with:
# - The repo_id
# - The filename: the saved model inside the repo and its extension (*.zip)

# %% [markdown]
# Because the model I download from the Hub was trained with Gym (the former version of Gymnasium) we need to install shimmy a API conversion tool that will help us to run the environment correctly.
#
# Shimmy Documentation: https://github.com/Farama-Foundation/Shimmy

# %%
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# ppo-LunarLander-v2.zip:   0%|          | 0.00/146k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.11.0-25-generic-x86_64-with-glibc2.39 # 25~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Tue Apr 15 17:20:50 UTC 2
# - Python: 3.10.12
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.7.0+cu126
# - GPU Enabled: True
# - Numpy: 1.23.5
# - Cloudpickle: 3.1.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.26.2
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.5.0
# PyTorch: 1.11.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0
# /home/gs/miniconda3/envs/rl/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %% [markdown]
# Let's evaluate this agent:

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=280.10 +/- 26.093667377382264

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! As you saw, the current agent is not doing great. As a first suggestion, you can train for more steps. With 1,000,000 steps, we saw some great results!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters for `PPO`. You can see them at https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters.
# * Check the [Stable-Baselines3 documentation](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) and try another model such as DQN.
# * **Push your new trained model** on the Hub 🔥
#
# **Compare the results of your LunarLander-v2 with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆
#
# Is moon landing too boring for you? Try to **change the environment**, why not use MountainCar-v0, CartPole-v1 or CarRacing-v0? Check how they work [using the gym documentation](https://www.gymlibrary.dev/) and have fun 🎉.

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter! That was the biggest one, **and there was a lot of information.**
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and have a solid foundations.
#
# Naturally, during the course, we’re going to dive deeper into these concepts but **it’s better to have a good understanding of them now before diving into the next chapters.**

# %% [markdown]
# Next time, in the bonus unit 1, you'll train Huggy the Dog to fetch the stick.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/huggy.jpg" alt="Huggy"/>
#
# ## Keep learning, stay awesome 🤗
